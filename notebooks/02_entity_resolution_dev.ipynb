# %% [markdown]
# # 02 - Entity Resolution Development
#
# ### Develop and tune the splink probabilistic entity resolution model for deduplicating supplier records accross ESG, pdf, ERP and open Supply hub data.
# ### steps:
#         1. Load and normalize the supplier name data from each source
#         2. Configure splink blocking rules and comparison functions
#         3. Train the Fellegi-Sunter model (EM algorithm)
#         4. Inspect match score distributions and calibrate threshold
#         5. Inspect false positives and false negatives.
#         6. Expect predictions -> run resolved_entities.py

# %%
import pandas as pd
import numpy as np
import random
from faker import Faker
from datetime import datetime, timedelta

# Initialize Faker
fake = Faker()
# Set seed for reproducibility
Faker.seed(42)
np.random.seed(42)

# %% [markdown]
# # 1. Load and Normalise Supplier Data
